# %% [markdown]
# <a href="https://www.kaggle.com/code/kennethnjuguna/automobile-dataset?scriptVersionId=133563805" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
#Reasing the data
        
automobile= pd.read_csv("/kaggle/input/automobile/automobile.csv")
automobile.head()

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/automobile/automobile.csv
#    symboling  normalized_losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# <h3>Reading the data and checking its details of the top five rows.</h3>

# %%
automobile.head()
# Out:
#    symboling  normalized_losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# <h3>Reading the data of the last five rows of the dataset.</h3>

# %%
automobile.tail()
# Out:
#      symboling  normalized_losses   make fuel-type aspiration num-of-doors  \
# 196         -1               95.0  volvo       gas        std         four
# 197         -1               95.0  volvo       gas      turbo         four
# 198         -1               95.0  volvo       gas        std         four
# 199         -1               95.0  volvo    diesel      turbo         four
# 200         -1               95.0  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 196      sedan          rwd           front       109.1  ...          141
# 197      sedan          rwd           front       109.1  ...          141
# 198      sedan          rwd           front       109.1  ...          173
# 199      sedan          rwd           front       109.1  ...          145
# 200      sedan          rwd           front       109.1  ...          141
#
# ...

# %% [markdown]
# <h3> Retrieve the details of all information of the dataset.</h3>

# %%
automobile.info
# Out:
# <bound method DataFrame.info of      symboling  normalized_losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1               95.0        volvo       gas        std
# 197         -1               95.0        volvo       gas      turbo
# 198         -1               95.0        volvo       gas        std
# 199         -1               95.0        volvo    diesel      turbo
# 200         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %% [markdown]
# Checking the type of data types within the automobile dataset.

# %% [markdown]
# <h3> Display the data types of each column header of the automobile dataset.</h3>

# %%
#Automobile datatypes
automobile.dtypes
# Out:
# symboling              int64
# normalized_losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %% [markdown]
# **Decribe the stastical values of the data**
#
# This will provide counts on the data provided by the dataset.

# %%
automobile.describe()
# Out:
#         symboling  normalized_losses  wheel-base      length       width  \
# count  201.000000         164.000000  201.000000  201.000000  201.000000
# mean     0.840796         122.000000   98.797015  174.200995   65.889055
# std      1.254802          35.442168    6.066366   12.322175    2.101471
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000          94.000000   94.500000  166.800000   64.100000
# 50%      1.000000         115.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.500000   66.600000
# max      3.000000         256.000000  120.900000  208.100000   72.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  197.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330711    3.256904
# std      2.447822   517.296727    41.546834    0.270793    0.319256
# ...

# %% [markdown]
# **We can also check all the attributes**
# In the function bracket we add include all

# %%
automobile.info
# Out:
# <bound method DataFrame.info of      symboling  normalized_losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1               95.0        volvo       gas        std
# 197         -1               95.0        volvo       gas      turbo
# 198         -1               95.0        volvo       gas        std
# 199         -1               95.0        volvo    diesel      turbo
# 200         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
# Make simple linearplot with the dataset

import seaborn as sns
sns.set_style('whitegrid')
sns.lmplot(x='engine-size', y='stroke', data=automobile)

# %% [markdown]
# **<h3>Cleaning of the data.</h3>**
#
# <p>Figure out the null values in your data.</p>

# %%
automobile.isnull().sum()
# Out:
# symboling             0
# normalized_losses    37
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %% [markdown]
# <h3> Cleaning the normalized-losses </h3>

# %%
#find how many normalized losses have the value "?"
automobile['normalized_losses'].loc[automobile['normalized_losses']=='?'].count()
# Out:
# 0

# %% [markdown]
# <h3>Do a detailed count on the number of vehicles in reference to the engine size.</h3>

# %%
#implement a distribution plot on The automobile dataset
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
automobile=pd.read_csv('/kaggle/input/automobile/automobile.csv')
sns.displot(automobile['engine-size'], kde= False, color='red')

# %% [markdown]
# <h3> Calculate number of vehicles in reference to curb weight.</h3>

# %%
#implement a distribution plot on The automobile dataset
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
automobile=pd.read_csv('/kaggle/input/automobile/automobile.csv')
sns.displot(automobile['curb-weight'], kde= False, color='blue')

# %% [markdown]
# <h3>Calculate number of vehicles in reference to price of the vehicle.</h3>

# %%
#implement a distribution plot on The automobile dataset
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
automobile=pd.read_csv('/kaggle/input/automobile/automobile.csv')
sns.displot(automobile['price'], kde= False, color='purple')

# %% [markdown]
# **Normalized losses based on No of wheels and body style**
# <p>Findings: As we understand the normalized loss which is the average loss payment per insured vehicle is calculated with many features of the cars which includes body style and no. of doors. Normalized losses are distributed across different body style but the two door cars has more number of losses than the four door cars.</p>

# %% [markdown]
# **Normalized losses based on No of wheels and body style**
# <p>Findings: As we understand the normalized loss which is the average loss payment per insured vehicle is calculated with many features of the cars which includes body style and no. of doors. Normalized losses are distributed across different body style but the two door cars has more number of losses than the four door cars.</p>

# %%
import matplotlib.pyplot as plt
automobile.make.value_counts().nlargest(10).plot(kind='bar', figsize=(15,5))
plt.title("Number of vehicles by make")
plt.ylabel('Number of vehicles')
plt.xlabel('Make');

# %% [markdown]
# **By the above analysis.**
#
#
# Most of the vehicles are of Toyota make which are Japenese.

# %%
import matplotlib.pyplot as plt
automobile.aspiration.value_counts().nlargest(10).plot(kind='bar',figsize=(15,5))
plt.title('Number of Vehicles by Aspiration')
plt.ylabel('Number of Vehicles')
plt.xlabel('Aspiration')
# Out:
# Text(0.5, 0, 'Aspiration')

# %% [markdown]
# **Insurance risk ratings histogram**

# %%
import pandas as pd
import matplotlib.pyplot as plt
automobile=pd.read_csv('/kaggle/input/automobile/automobile.csv')
automobile.symboling.hist(bins=5, color='green');
plt.title("Insurance risk ratings of vehicles")
plt.ylabel('Number of vehicles')
plt.xlabel('Risk rating');

# %% [markdown]
# **Normalized losses Histogram**

# %%
automobile['normalized_losses'].hist(bins=5,color='green')
plt.title("Normalized losses of Vehicles")
plt.ylabel('Number of Vehicles')
plt.xlabel('Normalized losses');

# %% [markdown]
# **Fuel type bar Chart**

# %%
automobile['fuel-type'].value_counts().plot(kind='bar',color='green')
plt.title('Fuel type frequence diagram')
plt.ylabel('Number of Vehicles')
plt.xlabel('Fuel Type');

# %% [markdown]
# **Engine type pie diagram**

# %%
automobile['aspiration'].value_counts().plot.pie(figsize=(8, 8),autopct='%.2f')
plt.title("Engine type pie diagram")
plt.ylabel("Number of vehicles")
plt.xlabel("Engine type")
# Out:
# Text(0.5, 0, 'Engine type')

# %% [markdown]
# **Body type pie chart**

# %%
automobile['body-style'].value_counts().plot.pie(figsize=(8, 8),autopct='%.2f')
plt.title('Body type Pie Diagram')
plt.ylabel('Number of Vehicles')
plt.xlabel('Body Type')
# Out:
# Text(0.5, 0, 'Body Type')

# %% [markdown]
# **Pie Chart on Body type**
#
# Most of the vehicles are of the sedan bodytype. The rest follow as described below
# * Sedan
# * Hatchback
# * Wagon
# * Hardtop
# * Convertible

# %% [markdown]
# **Pie chart of the Engine Location**

# %%
automobile['engine-location'].value_counts().plot.pie(figsize=(8,8),autopct='%.2f')
plt.title('Engine Location Pie Chart')
plt.ylabel('Number of Vehicles')
plt.xlabel('Engine Location')
# Out:
# Text(0.5, 0, 'Engine Location')

# %% [markdown]
# **From the above Engine Location pie chart**
#
# Most vehicles have their engines situated in the front as compared to the rear. This can be viewed as those vehicles with their engine on the front take **98.5%** as compared to the ones with their engine on the rear taking **1.49%**.

# %% [markdown]
# **Fuel Type Pie Chart Diagram**

# %%
automobile['fuel-type'].value_counts().plot.pie(figsize=(8,8),autopct='%.2f')
plt.title('Fuel type pie Chart Diagram')
plt.ylabel('Number of Vehicles')
plt.xlabel('Fuel Type')
# Out:
# Text(0.5, 0, 'Fuel Type')

# %% [markdown]
# **Analysis on Fuel Type for all the vehicles**
#
# Most vehicles are running on gas as compared to diesel.

# %% [markdown]
# **Drive wheels pie Chart Diagram**

# %%
automobile['drive-wheels'].value_counts().plot.pie(figsize=(8,8),autopct='%.2f')
plt.title('Drive Wheels Pie Chart')
plt.ylabel('Number of Vehicles')
plt.xlabel('Drive Wheels')
# Out:
# Text(0.5, 0, 'Drive Wheels')

# %% [markdown]
# **From the analysis of the pie chart above**
#
# Most of the vehicles are fwd.

# %% [markdown]
# **Scatter plot of City and Highway MPG, Curb weight.**
#
# Based on the scatter plot of the dataset, it is clear that both the city and highway Mpg is inversely propotional to curb weight.
#
# Heavier the Automobile less the mileage for both the city and highway.

# %% [markdown]
# **Number of doors bar chart**

# %%
automobile['num-of-doors'].value_counts().plot(kind='bar', color='purple')
plt.title('Number of doors frequency diagram')
plt.ylabel('Number of vehicles')
plt.xlabel('Number of doors')
# Out:
# Text(0.5, 0, 'Number of doors')

# %% [markdown]
# **Driver wheels bar chart**

# %%
automobile['drive-wheels'].value_counts().plot(kind='bar',color='red')
plt.title('Drive wheels diagram')
plt.ylabel('Number of vehicles')
plt.xlabel('Drive wheels')
# Out:
# Text(0.5, 0, 'Drive wheels')

# %% [markdown]
# **Findings**
#
# Through the automobile data analysis we have found the following findings:-
# * Toyota is the most preferred vehicle by most users with more than 40% than the 2nd highest Nissan.
# * Most preferred fuel type is Standard as compared to Turbo. Standard is 80% more of the choice.
# * On the type of Fuel most people prefer gas to diesel fuel type.
# * Most of the vehicles are in the engine size of 100.
# * Most people prefer four doored vehicles as compared to two doored vehicles.

# %% [markdown]
# **Scatter plot of price and engine size.**
#
# Findings the more the engine size the higher the price.

# %%
sns.lmplot(data=automobile,x='price',y='engine-size')

# %% [markdown]
# **Scatter plot of Engine Size and Peak RPM**

# %%
sns.scatterplot(data=automobile, x='engine-size',y='peak-rpm')
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='peak-rpm'>

# %% [markdown]
# **Scatter Plot on Wheel base and Engine size**

# %%
import seaborn as sns
sns.scatterplot(data=automobile, x= 'engine-size', y='wheel-base', hue='make')
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='wheel-base'>
